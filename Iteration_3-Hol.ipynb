# %%
import tensorflow as tf
from tensorflow.python.client import device_lib

print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
device_lib.list_local_devices()
# Out:
# Num GPUs Available:  1
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 8962121249366378330
#  xla_global_id: -1,
#  name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 4176478208
#  locality {
#    bus_id: 1
#    links {
#    }
#  }
#  incarnation: 11675917552145037370
#  physical_device_desc: "device: 0, name: NVIDIA GeForce GTX 1660 Ti, pci bus id: 0000:01:00.0, compute capability: 7.5"
#  xla_global_id: 416903419]

# %%
import tensorflow.keras.utils as np_utils
import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras import layers, optimizers
from tensorflow.keras.callbacks import LearningRateScheduler
from tensorflow.keras.layers import Input, Dense, LayerNormalization, Dropout, GRU
from tensorflow.keras import regularizers, callbacks
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import cv2
from imutils import paths
import shutil
import csv
from tqdm import tqdm
from sklearn.preprocessing import OneHotEncoder, LabelEncoder
from sklearn.metrics import accuracy_score
from keras.metrics import top_k_categorical_accuracy

# %%
train_accs = []
val_accs = []
train_losses = []
val_losses = []

class AccuracyHistoryCallback(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs=None):
        train_acc = logs.get('accuracy')
        val_acc = logs.get('val_accuracy')
        train_accs.append(train_acc)
        val_accs.append(val_acc)
        train_loss = logs.get('loss')
        val_loss = logs.get('val_loss')
        train_losses.append(train_loss)
        val_losses.append(val_loss)      

def lr_schedule(epoch):
    #if(MAX_FRAMES == 30):
        if epoch < 5:
            return 0.0001
        elif epoch < 12:
            return 0.00005
        else:
            return 0.00001
    #lse:
    #   if epoch < 5:
    #       return 0.00001
    #   elif epoch < 10:
    #       return 0.00001
    #   else:
    #       return 0.000005
    
accuracy_history = AccuracyHistoryCallback()       
top2_acc = lambda y_true, y_pred: top_k_categorical_accuracy(y_true, y_pred, k=2)
# Create a learning rate scheduler callback
def get_callbacks(filepath):
    return [
            keras.callbacks.EarlyStopping(
            monitor="val_accuracy",
            patience = 5,
            restore_best_weights=True
        ),
            keras.callbacks.ReduceLROnPlateau(
            monitor = "val_accuracy",
            factor = 0.5,
            patience = 3
        ),
            keras.callbacks.ModelCheckpoint(
            filepath,
            save_weights_only=True,
            save_best_only=True,
            verbose=1
            ),
            accuracy_history,
            lr_scheduler,
    ]

def GET_MODEL(MAX_FRAMES, MAX_KEYPOINTS):
    model = keras.models.Sequential()
    model.add(Dense(units=1024, input_shape=(MAX_FRAMES, MAX_KEYPOINTS)))
    model.add(LayerNormalization())
    model.add(Dropout(0.6))
    model.add(GRU(units=2048, return_sequences=True))
    model.add(LayerNormalization())
    model.add(Dropout(0.5))
    model.add(GRU(units=1024, return_sequences=True))
    model.add(LayerNormalization())
    model.add(Dropout(0.5))
    model.add(GRU(units=512, return_sequences=True))
    model.add(LayerNormalization())
    model.add(Dropout(0.5))
    model.add(GRU(units=256, return_sequences=True))
    model.add(LayerNormalization())
    model.add(Dropout(0.5))
    model.add(GRU(units=128, return_sequences=False))
    model.add(LayerNormalization())
    model.add(Dropout(0.1))
    model.add(Dense(units=20, activation='softmax'))
    optimizer = optimizers.Adam(learning_rate=0.0001)
    model.compile(optimizer=optimizer,
              loss="categorical_crossentropy",
              metrics=["accuracy",top2_acc])
    return model

# %%
all_classes = np.load('NPY_SPLITS/ALL_CLASSES.npy',allow_pickle=True)

# %%
MAX_KEYPOINTS = 270
lr_scheduler = LearningRateScheduler(lr_schedule)

for MAX_FRAMES in [90]:
    print(f"Training for frame count: {MAX_FRAMES}")
    for i in range(0, 5):
        print(f"Split: {i+1} Frames: {MAX_FRAMES}")
        train_filename = f"NPY_SPLITS/train_list_HPF_HOL_{MAX_FRAMES}_{i}.npy"
        train_label_filename = f"NPY_SPLITS/train_label_HPF_HOL_{MAX_FRAMES}_{i}.npy"
        test_filename = f"NPY_SPLITS/test_list_HPF_HOL_{MAX_FRAMES}_{i}.npy"
        test_label_filename = f"NPY_SPLITS/test_label_HPF_HOL_{MAX_FRAMES}_{i}.npy"
        train_list = np.load(train_filename, allow_pickle=True)
        train_label = np.load(train_label_filename, allow_pickle=True)
        test_list =  np.load(test_filename, allow_pickle=True)
        test_label = np.load(test_label_filename, allow_pickle=True)
        filepath_weights = f"SAVED_MODELS/IT3_HOL_{MAX_FRAMES}_{i}.hdf5"
        y_train_one_hot = np_utils.to_categorical(train_label)
        y_test_one_hot = np_utils.to_categorical(test_label)
        train_accs = []
        val_accs = []
        train_losses = []
        val_losses = []
        model=GET_MODEL(MAX_FRAMES, MAX_KEYPOINTS)
        model.fit(train_list, y_train_one_hot, epochs=16, batch_size=64, 
                  validation_data=(test_list, y_test_one_hot), 
                  callbacks=get_callbacks(filepath_weights))
        del train_filename, train_label_filename, test_filename, \
            test_label_filename, train_list, train_label, test_list, \
                test_label, model
        fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(8, 8))
        epochs = range(1, len(train_accs) + 1)
        # Plot the training and validation accuracy
        ax1.plot(epochs, train_accs, 'b', label='Training accuracy')
        ax1.plot(epochs, val_accs, 'r', label='Validation accuracy')
        ax1.set_title(f"Training and Validation Accuracy {MAX_FRAMES} Frames - IT3")
        ax1.set_xlabel('Epochs')
        ax1.set_ylabel('Accuracy')
        ax1.legend()
        
        # Plot the training and validation loss
        ax2.plot(epochs, train_losses, 'b', label='Training loss')
        ax2.plot(epochs, val_losses, 'r', label='Validation loss')
        ax2.set_title(f"Training and Validation Loss {MAX_FRAMES} Frames - IT3")
        ax2.set_xlabel('Epochs')
        ax2.set_ylabel('Loss')
        ax2.legend()
        
        # Adjust spacing between subplots
        plt.tight_layout()
        
        # Save the combined subplot to a file
        plt_filename = f"IT3-combined_plots{MAX_FRAMES}_{i}.png"
        plt.savefig(plt_filename)
        print("*************************DONE******************************")
# Out:
# Training for frame count: 90
# Split: 1 Frames: 90
# Epoch 1/16
#   6/137 [>.............................] - ETA: 52s - loss: 3.8327 - accuracy: 0.0547 - <lambda>: 0.1224WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1631s vs `on_train_batch_end` time: 0.1980s). Check your callbacks.
# 137/137 [==============================] - ETA: 0s - loss: 3.2522 - accuracy: 0.0604 - <lambda>: 0.1147
# Epoch 1: val_loss improved from inf to 3.02836, saving model to SAVED_MODELS\IT3_HOL_90_0.hdf5
# 137/137 [==============================] - 71s 462ms/step - loss: 3.2522 - accuracy: 0.0604 - <lambda>: 0.1147 - val_loss: 3.0284 - val_accuracy: 0.0525 - val_<lambda>: 0.1238 - lr: 1.0000e-04
# Epoch 2/16
# 137/137 [==============================] - ETA: 0s - loss: 3.1069 - accuracy: 0.0631 - <lambda>: 0.1212
# Epoch 2: val_loss improved from 3.02836 to 3.00321, saving model to SAVED_MODELS\IT3_HOL_90_0.hdf5
# 137/137 [==============================] - 62s 456ms/step - loss: 3.1069 - accuracy: 0.0631 - <lambda>: 0.1212 - val_loss: 3.0032 - val_accuracy: 0.0583 - val_<lambda>: 0.1133 - lr: 1.0000e-04
# Epoch 3/16
# 137/137 [==============================] - ETA: 0s - loss: 3.0816 - accuracy: 0.0630 - <lambda>: 0.1219
# Epoch 3: val_loss improved from 3.00321 to 2.99315, saving model to SAVED_MODELS\IT3_HOL_90_0.hdf5
# 137/137 [==============================] - 63s 458ms/step - loss: 3.0816 - accuracy: 0.0630 - <lambda>: 0.1219 - val_loss: 2.9931 - val_accuracy: 0.0600 - val_<lambda>: 0.1217 - lr: 1.0000e-04
# Epoch 4/16
# 137/137 [==============================] - ETA: 0s - loss: 3.0273 - accuracy: 0.0716 - <lambda>: 0.1377
# Epoch 4: val_loss improved from 2.99315 to 2.94460, saving model to SAVED_MODELS\IT3_HOL_90_0.hdf5
# 137/137 [==============================] - 63s 461ms/step - loss: 3.0273 - accuracy: 0.0716 - <lambda>: 0.1377 - val_loss: 2.9446 - val_accuracy: 0.0875 - val_<lambda>: 0.2004 - lr: 1.0000e-04
# Epoch 5/16
# 137/137 [==============================] - ETA: 0s - loss: 2.7047 - accuracy: 0.1443 - <lambda>: 0.2554
# Epoch 5: val_loss improved from 2.94460 to 2.66596, saving model to SAVED_MODELS\IT3_HOL_90_0.hdf5
# 137/137 [==============================] - 63s 462ms/step - loss: 2.7047 - accuracy: 0.1443 - <lambda>: 0.2554 - val_loss: 2.6660 - val_accuracy: 0.1963 - val_<lambda>: 0.3417 - lr: 1.0000e-04
# Epoch 6/16
# 137/137 [==============================] - ETA: 0s - loss: 2.0799 - accuracy: 0.2955 - <lambda>: 0.4692
# Epoch 6: val_loss improved from 2.66596 to 2.19562, saving model to SAVED_MODELS\IT3_HOL_90_0.hdf5
# 137/137 [==============================] - 63s 463ms/step - loss: 2.0799 - accuracy: 0.2955 - <lambda>: 0.4692 - val_loss: 2.1956 - val_accuracy: 0.3025 - val_<lambda>: 0.4550 - lr: 5.0000e-05
# Epoch 7/16
# 137/137 [==============================] - ETA: 0s - loss: 1.6315 - accuracy: 0.4287 - <lambda>: 0.6261
# Epoch 7: val_loss improved from 2.19562 to 1.76981, saving model to SAVED_MODELS\IT3_HOL_90_0.hdf5
# 137/137 [==============================] - 64s 464ms/step - loss: 1.6315 - accuracy: 0.4287 - <lambda>: 0.6261 - val_loss: 1.7698 - val_accuracy: 0.3946 - val_<lambda>: 0.5471 - lr: 5.0000e-05
# Epoch 8/16
# 137/137 [==============================] - ETA: 0s - loss: 1.2662 - accuracy: 0.5599 - <lambda>: 0.7457
# Epoch 8: val_loss improved from 1.76981 to 1.60169, saving model to SAVED_MODELS\IT3_HOL_90_0.hdf5
# 137/137 [==============================] - 64s 466ms/step - loss: 1.2662 - accuracy: 0.5599 - <lambda>: 0.7457 - val_loss: 1.6017 - val_accuracy: 0.4721 - val_<lambda>: 0.6625 - lr: 5.0000e-05
# Epoch 9/16
# 137/137 [==============================] - ETA: 0s - loss: 0.9141 - accuracy: 0.6965 - <lambda>: 0.8540
# Epoch 9: val_loss improved from 1.60169 to 1.40982, saving model to SAVED_MODELS\IT3_HOL_90_0.hdf5
# 137/137 [==============================] - 64s 468ms/step - loss: 0.9141 - accuracy: 0.6965 - <lambda>: 0.8540 - val_loss: 1.4098 - val_accuracy: 0.5387 - val_<lambda>: 0.7237 - lr: 5.0000e-05
# Epoch 10/16
# 137/137 [==============================] - ETA: 0s - loss: 0.6605 - accuracy: 0.7913 - <lambda>: 0.9094
# Epoch 10: val_loss improved from 1.40982 to 1.10420, saving model to SAVED_MODELS\IT3_HOL_90_0.hdf5
# 137/137 [==============================] - 64s 469ms/step - loss: 0.6605 - accuracy: 0.7913 - <lambda>: 0.9094 - val_loss: 1.1042 - val_accuracy: 0.6346 - val_<lambda>: 0.8096 - lr: 5.0000e-05
# Epoch 11/16
# 137/137 [==============================] - ETA: 0s - loss: 0.5040 - accuracy: 0.8445 - <lambda>: 0.9434
# Epoch 11: val_loss improved from 1.10420 to 0.97396, saving model to SAVED_MODELS\IT3_HOL_90_0.hdf5
# 137/137 [==============================] - 64s 470ms/step - loss: 0.5040 - accuracy: 0.8445 - <lambda>: 0.9434 - val_loss: 0.9740 - val_accuracy: 0.6754 - val_<lambda>: 0.8512 - lr: 5.0000e-05
# Epoch 12/16
# 137/137 [==============================] - ETA: 0s - loss: 0.3957 - accuracy: 0.8833 - <lambda>: 0.9608
# Epoch 12: val_loss improved from 0.97396 to 0.96979, saving model to SAVED_MODELS\IT3_HOL_90_0.hdf5
# 137/137 [==============================] - 64s 470ms/step - loss: 0.3957 - accuracy: 0.8833 - <lambda>: 0.9608 - val_loss: 0.9698 - val_accuracy: 0.6988 - val_<lambda>: 0.8675 - lr: 5.0000e-05
# Epoch 13/16
# 137/137 [==============================] - ETA: 0s - loss: 0.2721 - accuracy: 0.9323 - <lambda>: 0.9791
# Epoch 13: val_loss improved from 0.96979 to 0.81773, saving model to SAVED_MODELS\IT3_HOL_90_0.hdf5
# 137/137 [==============================] - 64s 470ms/step - loss: 0.2721 - accuracy: 0.9323 - <lambda>: 0.9791 - val_loss: 0.8177 - val_accuracy: 0.7246 - val_<lambda>: 0.8963 - lr: 1.0000e-05
# Epoch 14/16
# 137/137 [==============================] - ETA: 0s - loss: 0.2416 - accuracy: 0.9427 - <lambda>: 0.9821
# Epoch 14: val_loss did not improve from 0.81773
# 137/137 [==============================] - 64s 467ms/step - loss: 0.2416 - accuracy: 0.9427 - <lambda>: 0.9821 - val_loss: 0.8570 - val_accuracy: 0.7171 - val_<lambda>: 0.8817 - lr: 1.0000e-05
# Epoch 15/16
# 137/137 [==============================] - ETA: 0s - loss: 0.2220 - accuracy: 0.9467 - <lambda>: 0.9857
# Epoch 15: val_loss did not improve from 0.81773
# 137/137 [==============================] - 64s 469ms/step - loss: 0.2220 - accuracy: 0.9467 - <lambda>: 0.9857 - val_loss: 0.9937 - val_accuracy: 0.6929 - val_<lambda>: 0.8537 - lr: 1.0000e-05
# Epoch 16/16
# 137/137 [==============================] - ETA: 0s - loss: 0.2068 - accuracy: 0.9516 - <lambda>: 0.9858
# Epoch 16: val_loss improved from 0.81773 to 0.80419, saving model to SAVED_MODELS\IT3_HOL_90_0.hdf5
# 137/137 [==============================] - 65s 472ms/step - loss: 0.2068 - accuracy: 0.9516 - <lambda>: 0.9858 - val_loss: 0.8042 - val_accuracy: 0.7546 - val_<lambda>: 0.9017 - lr: 1.0000e-05
# *************************DONE******************************
# Split: 2 Frames: 90
# Epoch 1/16
#   6/137 [>.............................] - ETA: 55s - loss: 3.7503 - accuracy: 0.0599 - <lambda>: 0.1224WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1698s vs `on_train_batch_end` time: 0.2333s). Check your callbacks.
# 137/137 [==============================] - ETA: 0s - loss: 3.2737 - accuracy: 0.0563 - <lambda>: 0.1123
# Epoch 1: val_loss improved from inf to 3.02671, saving model to SAVED_MODELS\IT3_HOL_90_1.hdf5
# 137/137 [==============================] - 72s 476ms/step - loss: 3.2737 - accuracy: 0.0563 - <lambda>: 0.1123 - val_loss: 3.0267 - val_accuracy: 0.0525 - val_<lambda>: 0.0946 - lr: 1.0000e-04
# Epoch 2/16
# 137/137 [==============================] - ETA: 0s - loss: 3.1117 - accuracy: 0.0616 - <lambda>: 0.1201
# Epoch 2: val_loss improved from 3.02671 to 3.01056, saving model to SAVED_MODELS\IT3_HOL_90_1.hdf5
# 137/137 [==============================] - 64s 469ms/step - loss: 3.1117 - accuracy: 0.0616 - <lambda>: 0.1201 - val_loss: 3.0106 - val_accuracy: 0.0475 - val_<lambda>: 0.1025 - lr: 1.0000e-04
# Epoch 3/16
# 137/137 [==============================] - ETA: 0s - loss: 3.0809 - accuracy: 0.0578 - <lambda>: 0.1144
# Epoch 3: val_loss did not improve from 3.01056
# 137/137 [==============================] - 64s 468ms/step - loss: 3.0809 - accuracy: 0.0578 - <lambda>: 0.1144 - val_loss: 3.0110 - val_accuracy: 0.0429 - val_<lambda>: 0.0838 - lr: 1.0000e-04
# Epoch 4/16
# 137/137 [==============================] - ETA: 0s - loss: 3.0340 - accuracy: 0.0753 - <lambda>: 0.1389
# Epoch 4: val_loss improved from 3.01056 to 2.88931, saving model to SAVED_MODELS\IT3_HOL_90_1.hdf5
# 137/137 [==============================] - 64s 470ms/step - loss: 3.0340 - accuracy: 0.0753 - <lambda>: 0.1389 - val_loss: 2.8893 - val_accuracy: 0.0904 - val_<lambda>: 0.1688 - lr: 1.0000e-04
# Epoch 5/16
# 137/137 [==============================] - ETA: 0s - loss: 2.8066 - accuracy: 0.1315 - <lambda>: 0.2266
# Epoch 5: val_loss improved from 2.88931 to 2.44112, saving model to SAVED_MODELS\IT3_HOL_90_1.hdf5
# 137/137 [==============================] - 64s 470ms/step - loss: 2.8066 - accuracy: 0.1315 - <lambda>: 0.2266 - val_loss: 2.4411 - val_accuracy: 0.1996 - val_<lambda>: 0.3371 - lr: 1.0000e-04
# Epoch 6/16
# 137/137 [==============================] - ETA: 0s - loss: 2.1560 - accuracy: 0.2866 - <lambda>: 0.4575
# Epoch 6: val_loss improved from 2.44112 to 2.28229, saving model to SAVED_MODELS\IT3_HOL_90_1.hdf5
# 137/137 [==============================] - 65s 471ms/step - loss: 2.1560 - accuracy: 0.2866 - <lambda>: 0.4575 - val_loss: 2.2823 - val_accuracy: 0.2225 - val_<lambda>: 0.3821 - lr: 5.0000e-05
# Epoch 7/16
# 137/137 [==============================] - ETA: 0s - loss: 1.6021 - accuracy: 0.4428 - <lambda>: 0.6347
# Epoch 7: val_loss improved from 2.28229 to 1.92026, saving model to SAVED_MODELS\IT3_HOL_90_1.hdf5
# 137/137 [==============================] - 64s 471ms/step - loss: 1.6021 - accuracy: 0.4428 - <lambda>: 0.6347 - val_loss: 1.9203 - val_accuracy: 0.3562 - val_<lambda>: 0.5408 - lr: 5.0000e-05
# Epoch 8/16
# 137/137 [==============================] - ETA: 0s - loss: 1.2059 - accuracy: 0.5800 - <lambda>: 0.7644
# Epoch 8: val_loss improved from 1.92026 to 1.87398, saving model to SAVED_MODELS\IT3_HOL_90_1.hdf5
# 137/137 [==============================] - 65s 471ms/step - loss: 1.2059 - accuracy: 0.5800 - <lambda>: 0.7644 - val_loss: 1.8740 - val_accuracy: 0.3975 - val_<lambda>: 0.5804 - lr: 5.0000e-05
# Epoch 9/16
# 137/137 [==============================] - ETA: 0s - loss: 0.8347 - accuracy: 0.7197 - <lambda>: 0.8676
# Epoch 9: val_loss did not improve from 1.87398
# 137/137 [==============================] - 64s 470ms/step - loss: 0.8347 - accuracy: 0.7197 - <lambda>: 0.8676 - val_loss: 1.9186 - val_accuracy: 0.4542 - val_<lambda>: 0.6308 - lr: 5.0000e-05
# Epoch 10/16
# 137/137 [==============================] - ETA: 0s - loss: 0.5709 - accuracy: 0.8199 - <lambda>: 0.9275
# Epoch 10: val_loss did not improve from 1.87398
# 137/137 [==============================] - 64s 470ms/step - loss: 0.5709 - accuracy: 0.8199 - <lambda>: 0.9275 - val_loss: 1.9410 - val_accuracy: 0.5088 - val_<lambda>: 0.6908 - lr: 5.0000e-05
# Epoch 11/16
# 137/137 [==============================] - ETA: 0s - loss: 0.3989 - accuracy: 0.8809 - <lambda>: 0.9629
# Epoch 11: val_loss improved from 1.87398 to 1.80903, saving model to SAVED_MODELS\IT3_HOL_90_1.hdf5
# 137/137 [==============================] - 65s 472ms/step - loss: 0.3989 - accuracy: 0.8809 - <lambda>: 0.9629 - val_loss: 1.8090 - val_accuracy: 0.5650 - val_<lambda>: 0.7375 - lr: 5.0000e-05
# Epoch 12/16
# 137/137 [==============================] - ETA: 0s - loss: 0.2587 - accuracy: 0.9326 - <lambda>: 0.9825
# Epoch 12: val_loss did not improve from 1.80903
# 137/137 [==============================] - 64s 469ms/step - loss: 0.2587 - accuracy: 0.9326 - <lambda>: 0.9825 - val_loss: 2.0001 - val_accuracy: 0.5354 - val_<lambda>: 0.7267 - lr: 5.0000e-05
# Epoch 13/16
# 137/137 [==============================] - ETA: 0s - loss: 0.1608 - accuracy: 0.9658 - <lambda>: 0.9942
# Epoch 13: val_loss did not improve from 1.80903
# 137/137 [==============================] - 64s 469ms/step - loss: 0.1608 - accuracy: 0.9658 - <lambda>: 0.9942 - val_loss: 1.8374 - val_accuracy: 0.5763 - val_<lambda>: 0.7717 - lr: 1.0000e-05
# Epoch 14/16
# 137/137 [==============================] - ETA: 0s - loss: 0.1365 - accuracy: 0.9742 - <lambda>: 0.9953
# Epoch 14: val_loss did not improve from 1.80903
# 137/137 [==============================] - 64s 470ms/step - loss: 0.1365 - accuracy: 0.9742 - <lambda>: 0.9953 - val_loss: 1.9155 - val_accuracy: 0.5800 - val_<lambda>: 0.7592 - lr: 1.0000e-05
# Epoch 15/16
# 137/137 [==============================] - ETA: 0s - loss: 0.1246 - accuracy: 0.9782 - <lambda>: 0.9963
# Epoch 15: val_loss did not improve from 1.80903
# 137/137 [==============================] - 64s 470ms/step - loss: 0.1246 - accuracy: 0.9782 - <lambda>: 0.9963 - val_loss: 1.8699 - val_accuracy: 0.5879 - val_<lambda>: 0.7804 - lr: 1.0000e-05
# Epoch 16/16
# 137/137 [==============================] - ETA: 0s - loss: 0.1121 - accuracy: 0.9809 - <lambda>: 0.9971
# Epoch 16: val_loss improved from 1.80903 to 1.80392, saving model to SAVED_MODELS\IT3_HOL_90_1.hdf5
# 137/137 [==============================] - 64s 470ms/step - loss: 0.1121 - accuracy: 0.9809 - <lambda>: 0.9971 - val_loss: 1.8039 - val_accuracy: 0.6050 - val_<lambda>: 0.7858 - lr: 1.0000e-05
# *************************DONE******************************
# Split: 3 Frames: 90
# Epoch 1/16
#   6/137 [>.............................] - ETA: 55s - loss: 3.8367 - accuracy: 0.0391 - <lambda>: 0.0859WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1694s vs `on_train_batch_end` time: 0.2322s). Check your callbacks.
# 137/137 [==============================] - ETA: 0s - loss: 3.2975 - accuracy: 0.0557 - <lambda>: 0.1089
# Epoch 1: val_loss improved from inf to 3.00015, saving model to SAVED_MODELS\IT3_HOL_90_2.hdf5
# 137/137 [==============================] - 73s 478ms/step - loss: 3.2975 - accuracy: 0.0557 - <lambda>: 0.1089 - val_loss: 3.0002 - val_accuracy: 0.0463 - val_<lambda>: 0.1238 - lr: 1.0000e-04
# Epoch 2/16
# 137/137 [==============================] - ETA: 0s - loss: 3.1220 - accuracy: 0.0603 - <lambda>: 0.1123
# Epoch 2: val_loss improved from 3.00015 to 2.99978, saving model to SAVED_MODELS\IT3_HOL_90_2.hdf5
# 137/137 [==============================] - 64s 468ms/step - loss: 3.1220 - accuracy: 0.0603 - <lambda>: 0.1123 - val_loss: 2.9998 - val_accuracy: 0.0742 - val_<lambda>: 0.1179 - lr: 1.0000e-04
# Epoch 3/16
# 137/137 [==============================] - ETA: 0s - loss: 3.0590 - accuracy: 0.0671 - <lambda>: 0.1288
# Epoch 3: val_loss improved from 2.99978 to 2.91798, saving model to SAVED_MODELS\IT3_HOL_90_2.hdf5
# 137/137 [==============================] - 64s 469ms/step - loss: 3.0590 - accuracy: 0.0671 - <lambda>: 0.1288 - val_loss: 2.9180 - val_accuracy: 0.0950 - val_<lambda>: 0.1696 - lr: 1.0000e-04
# Epoch 4/16
# 137/137 [==============================] - ETA: 0s - loss: 2.8756 - accuracy: 0.1121 - <lambda>: 0.2016
# Epoch 4: val_loss improved from 2.91798 to 2.56797, saving model to SAVED_MODELS\IT3_HOL_90_2.hdf5
# 137/137 [==============================] - 64s 469ms/step - loss: 2.8756 - accuracy: 0.1121 - <lambda>: 0.2016 - val_loss: 2.5680 - val_accuracy: 0.2142 - val_<lambda>: 0.3258 - lr: 1.0000e-04
# Epoch 5/16
# 137/137 [==============================] - ETA: 0s - loss: 2.3674 - accuracy: 0.2232 - <lambda>: 0.3803
# Epoch 5: val_loss improved from 2.56797 to 2.01671, saving model to SAVED_MODELS\IT3_HOL_90_2.hdf5
# 137/137 [==============================] - 64s 470ms/step - loss: 2.3674 - accuracy: 0.2232 - <lambda>: 0.3803 - val_loss: 2.0167 - val_accuracy: 0.3329 - val_<lambda>: 0.4992 - lr: 1.0000e-04
# Epoch 6/16
# 137/137 [==============================] - ETA: 0s - loss: 1.7401 - accuracy: 0.3804 - <lambda>: 0.5817
# Epoch 6: val_loss improved from 2.01671 to 1.73246, saving model to SAVED_MODELS\IT3_HOL_90_2.hdf5
# 137/137 [==============================] - 64s 469ms/step - loss: 1.7401 - accuracy: 0.3804 - <lambda>: 0.5817 - val_loss: 1.7325 - val_accuracy: 0.4175 - val_<lambda>: 0.6271 - lr: 5.0000e-05
# Epoch 7/16
# 137/137 [==============================] - ETA: 0s - loss: 1.3785 - accuracy: 0.5078 - <lambda>: 0.6951
# Epoch 7: val_loss improved from 1.73246 to 1.43118, saving model to SAVED_MODELS\IT3_HOL_90_2.hdf5
# 137/137 [==============================] - 64s 470ms/step - loss: 1.3785 - accuracy: 0.5078 - <lambda>: 0.6951 - val_loss: 1.4312 - val_accuracy: 0.4700 - val_<lambda>: 0.6933 - lr: 5.0000e-05
# Epoch 8/16
# 137/137 [==============================] - ETA: 0s - loss: 1.0708 - accuracy: 0.6325 - <lambda>: 0.7994
# Epoch 8: val_loss improved from 1.43118 to 1.20116, saving model to SAVED_MODELS\IT3_HOL_90_2.hdf5
# 137/137 [==============================] - 64s 471ms/step - loss: 1.0708 - accuracy: 0.6325 - <lambda>: 0.7994 - val_loss: 1.2012 - val_accuracy: 0.5754 - val_<lambda>: 0.7717 - lr: 5.0000e-05
# Epoch 9/16
# 137/137 [==============================] - ETA: 0s - loss: 0.7855 - accuracy: 0.7370 - <lambda>: 0.8737
# Epoch 9: val_loss improved from 1.20116 to 1.09188, saving model to SAVED_MODELS\IT3_HOL_90_2.hdf5
# 137/137 [==============================] - 64s 471ms/step - loss: 0.7855 - accuracy: 0.7370 - <lambda>: 0.8737 - val_loss: 1.0919 - val_accuracy: 0.6608 - val_<lambda>: 0.7937 - lr: 5.0000e-05
# Epoch 10/16
# 137/137 [==============================] - ETA: 0s - loss: 0.5912 - accuracy: 0.8130 - <lambda>: 0.9106
# Epoch 10: val_loss improved from 1.09188 to 0.99516, saving model to SAVED_MODELS\IT3_HOL_90_2.hdf5
# 137/137 [==============================] - 64s 471ms/step - loss: 0.5912 - accuracy: 0.8130 - <lambda>: 0.9106 - val_loss: 0.9952 - val_accuracy: 0.6896 - val_<lambda>: 0.8258 - lr: 5.0000e-05
# Epoch 11/16
# 137/137 [==============================] - ETA: 0s - loss: 0.4726 - accuracy: 0.8513 - <lambda>: 0.9403
# Epoch 11: val_loss improved from 0.99516 to 0.88302, saving model to SAVED_MODELS\IT3_HOL_90_2.hdf5
# 137/137 [==============================] - 64s 470ms/step - loss: 0.4726 - accuracy: 0.8513 - <lambda>: 0.9403 - val_loss: 0.8830 - val_accuracy: 0.7121 - val_<lambda>: 0.8767 - lr: 5.0000e-05
# Epoch 12/16
# 137/137 [==============================] - ETA: 0s - loss: 0.3835 - accuracy: 0.8840 - <lambda>: 0.9583
# Epoch 12: val_loss improved from 0.88302 to 0.71065, saving model to SAVED_MODELS\IT3_HOL_90_2.hdf5
# 137/137 [==============================] - 64s 470ms/step - loss: 0.3835 - accuracy: 0.8840 - <lambda>: 0.9583 - val_loss: 0.7106 - val_accuracy: 0.7958 - val_<lambda>: 0.9125 - lr: 5.0000e-05
# Epoch 13/16
# 137/137 [==============================] - ETA: 0s - loss: 0.2618 - accuracy: 0.9317 - <lambda>: 0.9780
# Epoch 13: val_loss improved from 0.71065 to 0.67220, saving model to SAVED_MODELS\IT3_HOL_90_2.hdf5
# 137/137 [==============================] - 64s 470ms/step - loss: 0.2618 - accuracy: 0.9317 - <lambda>: 0.9780 - val_loss: 0.6722 - val_accuracy: 0.7987 - val_<lambda>: 0.9117 - lr: 1.0000e-05
# Epoch 14/16
# 137/137 [==============================] - ETA: 0s - loss: 0.2366 - accuracy: 0.9425 - <lambda>: 0.9806
# Epoch 14: val_loss improved from 0.67220 to 0.60530, saving model to SAVED_MODELS\IT3_HOL_90_2.hdf5
# 137/137 [==============================] - 64s 470ms/step - loss: 0.2366 - accuracy: 0.9425 - <lambda>: 0.9806 - val_loss: 0.6053 - val_accuracy: 0.8213 - val_<lambda>: 0.9250 - lr: 1.0000e-05
# Epoch 15/16
# 137/137 [==============================] - ETA: 0s - loss: 0.2108 - accuracy: 0.9510 - <lambda>: 0.9853
# Epoch 15: val_loss did not improve from 0.60530
# 137/137 [==============================] - 64s 469ms/step - loss: 0.2108 - accuracy: 0.9510 - <lambda>: 0.9853 - val_loss: 0.6616 - val_accuracy: 0.8050 - val_<lambda>: 0.9187 - lr: 1.0000e-05
# Epoch 16/16
# 137/137 [==============================] - ETA: 0s - loss: 0.1959 - accuracy: 0.9567 - <lambda>: 0.9874
# Epoch 16: val_loss improved from 0.60530 to 0.60092, saving model to SAVED_MODELS\IT3_HOL_90_2.hdf5
# 137/137 [==============================] - 64s 471ms/step - loss: 0.1959 - accuracy: 0.9567 - <lambda>: 0.9874 - val_loss: 0.6009 - val_accuracy: 0.8296 - val_<lambda>: 0.9233 - lr: 1.0000e-05
# *************************DONE******************************
# Split: 4 Frames: 90
# Epoch 1/16
#   6/138 [>.............................] - ETA: 55s - loss: 3.8883 - accuracy: 0.0339 - <lambda>: 0.0911WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1697s vs `on_train_batch_end` time: 0.2356s). Check your callbacks.
# 138/138 [==============================] - ETA: 0s - loss: 3.2486 - accuracy: 0.0544 - <lambda>: 0.1102
# Epoch 1: val_loss improved from inf to 3.01766, saving model to SAVED_MODELS\IT3_HOL_90_3.hdf5
# 138/138 [==============================] - 72s 475ms/step - loss: 3.2486 - accuracy: 0.0544 - <lambda>: 0.1102 - val_loss: 3.0177 - val_accuracy: 0.0692 - val_<lambda>: 0.1262 - lr: 1.0000e-04
# Epoch 2/16
# 138/138 [==============================] - ETA: 0s - loss: 3.1090 - accuracy: 0.0609 - <lambda>: 0.1210
# Epoch 2: val_loss did not improve from 3.01766
# 138/138 [==============================] - 64s 463ms/step - loss: 3.1090 - accuracy: 0.0609 - <lambda>: 0.1210 - val_loss: 3.0315 - val_accuracy: 0.0713 - val_<lambda>: 0.1460 - lr: 1.0000e-04
# Epoch 3/16
# 138/138 [==============================] - ETA: 0s - loss: 3.0259 - accuracy: 0.0739 - <lambda>: 0.1428
# Epoch 3: val_loss improved from 3.01766 to 2.95628, saving model to SAVED_MODELS\IT3_HOL_90_3.hdf5
# 138/138 [==============================] - 64s 465ms/step - loss: 3.0259 - accuracy: 0.0739 - <lambda>: 0.1428 - val_loss: 2.9563 - val_accuracy: 0.0781 - val_<lambda>: 0.1789 - lr: 1.0000e-04
# Epoch 4/16
# 138/138 [==============================] - ETA: 0s - loss: 2.7618 - accuracy: 0.1315 - <lambda>: 0.2288
# Epoch 4: val_loss improved from 2.95628 to 2.64228, saving model to SAVED_MODELS\IT3_HOL_90_3.hdf5
# 138/138 [==============================] - 64s 466ms/step - loss: 2.7618 - accuracy: 0.1315 - <lambda>: 0.2288 - val_loss: 2.6423 - val_accuracy: 0.1586 - val_<lambda>: 0.2764 - lr: 1.0000e-04
# Epoch 5/16
# 138/138 [==============================] - ETA: 0s - loss: 2.1601 - accuracy: 0.2760 - <lambda>: 0.4414
# Epoch 5: val_loss improved from 2.64228 to 2.23941, saving model to SAVED_MODELS\IT3_HOL_90_3.hdf5
# 138/138 [==============================] - 64s 466ms/step - loss: 2.1601 - accuracy: 0.2760 - <lambda>: 0.4414 - val_loss: 2.2394 - val_accuracy: 0.2511 - val_<lambda>: 0.4570 - lr: 1.0000e-04
# Epoch 6/16
# 138/138 [==============================] - ETA: 0s - loss: 1.5352 - accuracy: 0.4609 - <lambda>: 0.6545
# Epoch 6: val_loss improved from 2.23941 to 2.17056, saving model to SAVED_MODELS\IT3_HOL_90_3.hdf5
# 138/138 [==============================] - 64s 466ms/step - loss: 1.5352 - accuracy: 0.4609 - <lambda>: 0.6545 - val_loss: 2.1706 - val_accuracy: 0.3135 - val_<lambda>: 0.4932 - lr: 5.0000e-05
# Epoch 7/16
# 138/138 [==============================] - ETA: 0s - loss: 1.2031 - accuracy: 0.5833 - <lambda>: 0.7672
# Epoch 7: val_loss improved from 2.17056 to 1.90874, saving model to SAVED_MODELS\IT3_HOL_90_3.hdf5
# 138/138 [==============================] - 64s 466ms/step - loss: 1.2031 - accuracy: 0.5833 - <lambda>: 0.7672 - val_loss: 1.9087 - val_accuracy: 0.3730 - val_<lambda>: 0.5937 - lr: 5.0000e-05
# Epoch 8/16
# 138/138 [==============================] - ETA: 0s - loss: 0.8898 - accuracy: 0.7028 - <lambda>: 0.8585
# Epoch 8: val_loss improved from 1.90874 to 1.78787, saving model to SAVED_MODELS\IT3_HOL_90_3.hdf5
# 138/138 [==============================] - 64s 466ms/step - loss: 0.8898 - accuracy: 0.7028 - <lambda>: 0.8585 - val_loss: 1.7879 - val_accuracy: 0.4637 - val_<lambda>: 0.6620 - lr: 5.0000e-05
# Epoch 9/16
# 138/138 [==============================] - ETA: 0s - loss: 0.6743 - accuracy: 0.7871 - <lambda>: 0.9089
# Epoch 9: val_loss improved from 1.78787 to 1.68628, saving model to SAVED_MODELS\IT3_HOL_90_3.hdf5
# 138/138 [==============================] - 64s 465ms/step - loss: 0.6743 - accuracy: 0.7871 - <lambda>: 0.9089 - val_loss: 1.6863 - val_accuracy: 0.4920 - val_<lambda>: 0.7127 - lr: 5.0000e-05
# Epoch 10/16
# 138/138 [==============================] - ETA: 0s - loss: 0.5278 - accuracy: 0.8379 - <lambda>: 0.9362
# Epoch 10: val_loss improved from 1.68628 to 1.21789, saving model to SAVED_MODELS\IT3_HOL_90_3.hdf5
# 138/138 [==============================] - 64s 465ms/step - loss: 0.5278 - accuracy: 0.8379 - <lambda>: 0.9362 - val_loss: 1.2179 - val_accuracy: 0.6000 - val_<lambda>: 0.8004 - lr: 5.0000e-05
# Epoch 11/16
# 138/138 [==============================] - ETA: 0s - loss: 0.4207 - accuracy: 0.8759 - <lambda>: 0.9557
# Epoch 11: val_loss did not improve from 1.21789
# 138/138 [==============================] - 64s 464ms/step - loss: 0.4207 - accuracy: 0.8759 - <lambda>: 0.9557 - val_loss: 1.5657 - val_accuracy: 0.5574 - val_<lambda>: 0.7599 - lr: 5.0000e-05
# Epoch 12/16
# 138/138 [==============================] - ETA: 0s - loss: 0.2947 - accuracy: 0.9205 - <lambda>: 0.9725
# Epoch 12: val_loss did not improve from 1.21789
# 138/138 [==============================] - 64s 464ms/step - loss: 0.2947 - accuracy: 0.9205 - <lambda>: 0.9725 - val_loss: 1.2827 - val_accuracy: 0.6198 - val_<lambda>: 0.8236 - lr: 5.0000e-05
# Epoch 13/16
# 138/138 [==============================] - ETA: 0s - loss: 0.2142 - accuracy: 0.9481 - <lambda>: 0.9826
# Epoch 13: val_loss did not improve from 1.21789
# 138/138 [==============================] - 64s 464ms/step - loss: 0.2142 - accuracy: 0.9481 - <lambda>: 0.9826 - val_loss: 1.3383 - val_accuracy: 0.6236 - val_<lambda>: 0.8148 - lr: 1.0000e-05
# Epoch 14/16
# 138/138 [==============================] - ETA: 0s - loss: 0.1859 - accuracy: 0.9598 - <lambda>: 0.9860
# Epoch 14: val_loss did not improve from 1.21789
# 138/138 [==============================] - 64s 464ms/step - loss: 0.1859 - accuracy: 0.9598 - <lambda>: 0.9860 - val_loss: 1.3123 - val_accuracy: 0.6338 - val_<lambda>: 0.8253 - lr: 1.0000e-05
# Epoch 15/16
# 138/138 [==============================] - ETA: 0s - loss: 0.1712 - accuracy: 0.9622 - <lambda>: 0.9867
# Epoch 15: val_loss did not improve from 1.21789
# 138/138 [==============================] - 64s 463ms/step - loss: 0.1712 - accuracy: 0.9622 - <lambda>: 0.9867 - val_loss: 1.3977 - val_accuracy: 0.6300 - val_<lambda>: 0.8127 - lr: 1.0000e-05
# Epoch 16/16
# 138/138 [==============================] - ETA: 0s - loss: 0.1672 - accuracy: 0.9625 - <lambda>: 0.9870
# Epoch 16: val_loss did not improve from 1.21789
# 138/138 [==============================] - 64s 463ms/step - loss: 0.1672 - accuracy: 0.9625 - <lambda>: 0.9870 - val_loss: 1.4502 - val_accuracy: 0.6228 - val_<lambda>: 0.7979 - lr: 1.0000e-05
# *************************DONE******************************
# Split: 5 Frames: 90
# Epoch 1/16
#   6/134 [>.............................] - ETA: 53s - loss: 3.7477 - accuracy: 0.0312 - <lambda>: 0.0911WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1697s vs `on_train_batch_end` time: 0.2315s). Check your callbacks.
# 134/134 [==============================] - ETA: 0s - loss: 3.2619 - accuracy: 0.0571 - <lambda>: 0.1118
# Epoch 1: val_loss improved from inf to 3.00794, saving model to SAVED_MODELS\IT3_HOL_90_4.hdf5
# 134/134 [==============================] - 70s 482ms/step - loss: 3.2619 - accuracy: 0.0571 - <lambda>: 0.1118 - val_loss: 3.0079 - val_accuracy: 0.0464 - val_<lambda>: 0.1214 - lr: 1.0000e-04
# Epoch 2/16
# 134/134 [==============================] - ETA: 0s - loss: 3.1093 - accuracy: 0.0560 - <lambda>: 0.1165
# Epoch 2: val_loss improved from 3.00794 to 2.99939, saving model to SAVED_MODELS\IT3_HOL_90_4.hdf5
# 134/134 [==============================] - 63s 471ms/step - loss: 3.1093 - accuracy: 0.0560 - <lambda>: 0.1165 - val_loss: 2.9994 - val_accuracy: 0.0947 - val_<lambda>: 0.1311 - lr: 1.0000e-04
# Epoch 3/16
# 134/134 [==============================] - ETA: 0s - loss: 3.0777 - accuracy: 0.0652 - <lambda>: 0.1247
# Epoch 3: val_loss improved from 2.99939 to 2.99540, saving model to SAVED_MODELS\IT3_HOL_90_4.hdf5
# 134/134 [==============================] - 63s 471ms/step - loss: 3.0777 - accuracy: 0.0652 - <lambda>: 0.1247 - val_loss: 2.9954 - val_accuracy: 0.0634 - val_<lambda>: 0.1613 - lr: 1.0000e-04
# Epoch 4/16
# 134/134 [==============================] - ETA: 0s - loss: 3.0533 - accuracy: 0.0637 - <lambda>: 0.1228
# Epoch 4: val_loss improved from 2.99540 to 2.92704, saving model to SAVED_MODELS\IT3_HOL_90_4.hdf5
# 134/134 [==============================] - 63s 472ms/step - loss: 3.0533 - accuracy: 0.0637 - <lambda>: 0.1228 - val_loss: 2.9270 - val_accuracy: 0.0916 - val_<lambda>: 0.1624 - lr: 1.0000e-04
# Epoch 5/16
# 134/134 [==============================] - ETA: 0s - loss: 2.9091 - accuracy: 0.1023 - <lambda>: 0.1899
# Epoch 5: val_loss improved from 2.92704 to 2.61155, saving model to SAVED_MODELS\IT3_HOL_90_4.hdf5
# 134/134 [==============================] - 63s 473ms/step - loss: 2.9091 - accuracy: 0.1023 - <lambda>: 0.1899 - val_loss: 2.6116 - val_accuracy: 0.1721 - val_<lambda>: 0.2927 - lr: 1.0000e-04
# Epoch 6/16
# 134/134 [==============================] - ETA: 0s - loss: 2.4944 - accuracy: 0.1952 - <lambda>: 0.3303
# Epoch 6: val_loss improved from 2.61155 to 2.16741, saving model to SAVED_MODELS\IT3_HOL_90_4.hdf5
# 134/134 [==============================] - 63s 473ms/step - loss: 2.4944 - accuracy: 0.1952 - <lambda>: 0.3303 - val_loss: 2.1674 - val_accuracy: 0.2738 - val_<lambda>: 0.4679 - lr: 5.0000e-05
# Epoch 7/16
# 134/134 [==============================] - ETA: 0s - loss: 2.0527 - accuracy: 0.2881 - <lambda>: 0.4743
# Epoch 7: val_loss improved from 2.16741 to 1.95602, saving model to SAVED_MODELS\IT3_HOL_90_4.hdf5
# 134/134 [==============================] - 63s 472ms/step - loss: 2.0527 - accuracy: 0.2881 - <lambda>: 0.4743 - val_loss: 1.9560 - val_accuracy: 0.3012 - val_<lambda>: 0.5143 - lr: 5.0000e-05
# Epoch 8/16
# 134/134 [==============================] - ETA: 0s - loss: 1.6585 - accuracy: 0.4156 - <lambda>: 0.6108
# Epoch 8: val_loss improved from 1.95602 to 1.63886, saving model to SAVED_MODELS\IT3_HOL_90_4.hdf5
# 134/134 [==============================] - 63s 474ms/step - loss: 1.6585 - accuracy: 0.4156 - <lambda>: 0.6108 - val_loss: 1.6389 - val_accuracy: 0.4312 - val_<lambda>: 0.6257 - lr: 5.0000e-05
# Epoch 9/16
# 134/134 [==============================] - ETA: 0s - loss: 1.3172 - accuracy: 0.5351 - <lambda>: 0.7284
# Epoch 9: val_loss improved from 1.63886 to 1.55327, saving model to SAVED_MODELS\IT3_HOL_90_4.hdf5
# 134/134 [==============================] - 64s 474ms/step - loss: 1.3172 - accuracy: 0.5351 - <lambda>: 0.7284 - val_loss: 1.5533 - val_accuracy: 0.4892 - val_<lambda>: 0.6589 - lr: 5.0000e-05
# Epoch 10/16
# 134/134 [==============================] - ETA: 0s - loss: 1.0076 - accuracy: 0.6538 - <lambda>: 0.8168
# Epoch 10: val_loss improved from 1.55327 to 1.23355, saving model to SAVED_MODELS\IT3_HOL_90_4.hdf5
# 134/134 [==============================] - 63s 474ms/step - loss: 1.0076 - accuracy: 0.6538 - <lambda>: 0.8168 - val_loss: 1.2336 - val_accuracy: 0.6156 - val_<lambda>: 0.7641 - lr: 5.0000e-05
# Epoch 11/16
# 134/134 [==============================] - ETA: 0s - loss: 0.7498 - accuracy: 0.7491 - <lambda>: 0.8840
# Epoch 11: val_loss improved from 1.23355 to 1.02973, saving model to SAVED_MODELS\IT3_HOL_90_4.hdf5
# 134/134 [==============================] - 63s 474ms/step - loss: 0.7498 - accuracy: 0.7491 - <lambda>: 0.8840 - val_loss: 1.0297 - val_accuracy: 0.6779 - val_<lambda>: 0.8357 - lr: 5.0000e-05
# Epoch 12/16
# 134/134 [==============================] - ETA: 0s - loss: 0.5532 - accuracy: 0.8245 - <lambda>: 0.9289
# Epoch 12: val_loss improved from 1.02973 to 0.99279, saving model to SAVED_MODELS\IT3_HOL_90_4.hdf5
# 134/134 [==============================] - 63s 473ms/step - loss: 0.5532 - accuracy: 0.8245 - <lambda>: 0.9289 - val_loss: 0.9928 - val_accuracy: 0.6879 - val_<lambda>: 0.8484 - lr: 5.0000e-05
# Epoch 13/16
# 134/134 [==============================] - ETA: 0s - loss: 0.4041 - accuracy: 0.8803 - <lambda>: 0.9570
# Epoch 13: val_loss improved from 0.99279 to 0.86404, saving model to SAVED_MODELS\IT3_HOL_90_4.hdf5
# 134/134 [==============================] - 63s 474ms/step - loss: 0.4041 - accuracy: 0.8803 - <lambda>: 0.9570 - val_loss: 0.8640 - val_accuracy: 0.7479 - val_<lambda>: 0.8689 - lr: 1.0000e-05
# Epoch 14/16
# 134/134 [==============================] - ETA: 0s - loss: 0.3521 - accuracy: 0.9020 - <lambda>: 0.9666
# Epoch 14: val_loss did not improve from 0.86404
# 134/134 [==============================] - 63s 473ms/step - loss: 0.3521 - accuracy: 0.9020 - <lambda>: 0.9666 - val_loss: 0.9004 - val_accuracy: 0.7456 - val_<lambda>: 0.8643 - lr: 1.0000e-05
# Epoch 15/16
# 134/134 [==============================] - ETA: 0s - loss: 0.3289 - accuracy: 0.9090 - <lambda>: 0.9701
# Epoch 15: val_loss did not improve from 0.86404
# 134/134 [==============================] - 63s 472ms/step - loss: 0.3289 - accuracy: 0.9090 - <lambda>: 0.9701 - val_loss: 0.8867 - val_accuracy: 0.7405 - val_<lambda>: 0.8677 - lr: 1.0000e-05
# Epoch 16/16
# 134/134 [==============================] - ETA: 0s - loss: 0.3021 - accuracy: 0.9195 - <lambda>: 0.9746
# Epoch 16: val_loss improved from 0.86404 to 0.78923, saving model to SAVED_MODELS\IT3_HOL_90_4.hdf5
# 134/134 [==============================] - 64s 474ms/step - loss: 0.3021 - accuracy: 0.9195 - <lambda>: 0.9746 - val_loss: 0.7892 - val_accuracy: 0.7668 - val_<lambda>: 0.8828 - lr: 1.0000e-05
# *************************DONE******************************

# %%
for MAX_FRAMES in [90]:
    losses = []
    accuracies = []
    k_accuracies = []
    print(f"Eval for frame count: {MAX_FRAMES}")
    for i in range(0, 5):
        test_filename = f"NPY_SPLITS/test_list_HPF_HOL_{MAX_FRAMES}_{i}.npy"
        test_label_filename = f"NPY_SPLITS/test_label_HPF_HOL_{MAX_FRAMES}_{i}.npy"
        
        test_list_val =  np.load(test_filename, allow_pickle=True)
        test_label_val = np.load(test_label_filename, allow_pickle=True)
        y_train_one_hot_val = np_utils.to_categorical(test_label_val)
        filepath_weights = f"SAVED_MODELS/IT3_HOL_{MAX_FRAMES}_{i}.hdf5"
        model=GET_MODEL(MAX_FRAMES, MAX_KEYPOINTS)        
        model.load_weights(filepath_weights)
        loss, accuracy, k_accuracy = model.evaluate(test_list_val, y_train_one_hot_val)
        losses.append(loss)
        accuracies.append(accuracy)
        k_accuracies.append(k_accuracy)
    avg_loss = sum(losses) / len(losses)
    avg_accuracy = sum(accuracies) / len(accuracies)
    avg_k_accuracy = sum(k_accuracies) / len(k_accuracies)
    # Print the average results
    print(f"Average Loss with {MAX_FRAMES} frames model:", avg_loss)
    print(f"Average Accuracy with {MAX_FRAMES} frames model:", avg_accuracy*100)
    print(f"Average K-Accuracy with {MAX_FRAMES} frames model:", avg_k_accuracy*100)
# Out:
# Eval for frame count: 90
# 75/75 [==============================] - 8s 74ms/step - loss: 0.8042 - accuracy: 0.7546 - <lambda>: 0.9017
# 75/75 [==============================] - 8s 74ms/step - loss: 1.8039 - accuracy: 0.6050 - <lambda>: 0.7858
# 75/75 [==============================] - 8s 73ms/step - loss: 0.6009 - accuracy: 0.8296 - <lambda>: 0.9233
# 75/75 [==============================] - 8s 74ms/step - loss: 1.2179 - accuracy: 0.6000 - <lambda>: 0.8004
# 81/81 [==============================] - 9s 74ms/step - loss: 0.7892 - accuracy: 0.7668 - <lambda>: 0.8828
# Average Loss with 90 frames model: 1.0432279706001282
# Average Accuracy with 90 frames model: 71.11976146697998
# Average K-Accuracy with 90 frames model: 85.8817183971405
