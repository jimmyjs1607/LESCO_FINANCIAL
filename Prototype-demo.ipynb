# %%
import video_tools as video_tools
import tkinter as tk
from tkinter import filedialog

# %%
VIDEO_PATH = "C:/Users/jimmy/Documents/ORIGINALES"
filepath_weights = f"SAVED_MODELS/IT5_HOL_30_4.hdf5"
FRAMES_SAMPLED = 30
KEYPOINTS_BASELINE_FACE_PCA = 202
model=video_tools.get_model_GRU(filepath_weights, FRAMES_SAMPLED, KEYPOINTS_BASELINE_FACE_PCA)
root = tk.Tk()
root.withdraw()
root.attributes("-topmost", True)
# Prompt the user to select a file
# Out:
# ''

# %%
file_path = filedialog.askopenfilename()
print("Segunda mejor prediccion:  " + video_tools.predict_sign_visual(model, file_path))
# Out:
# Segunda mejor prediccion:  Pagar
