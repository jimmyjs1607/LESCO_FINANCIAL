# %%
import tensorflow as tf
from tensorflow.python.client import device_lib

print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
device_lib.list_local_devices()
# Out:
# Num GPUs Available:  1
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 2234671165755074891
#  xla_global_id: -1,
#  name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 4176478208
#  locality {
#    bus_id: 1
#    links {
#    }
#  }
#  incarnation: 16146240275994069974
#  physical_device_desc: "device: 0, name: NVIDIA GeForce GTX 1660 Ti, pci bus id: 0000:01:00.0, compute capability: 7.5"
#  xla_global_id: 416903419]

# %%
import tensorflow.keras.utils as np_utils
import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras import layers, optimizers
from tensorflow.keras.callbacks import LearningRateScheduler
from tensorflow.keras.layers import Input, Dense, LayerNormalization, Dropout, GRU
from tensorflow.keras import regularizers, callbacks
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import cv2
from imutils import paths
import shutil
import csv
from tqdm import tqdm
from sklearn.preprocessing import OneHotEncoder, LabelEncoder
from sklearn.metrics import accuracy_score
from keras.metrics import top_k_categorical_accuracy

# %%
train_accs = []
val_accs = []
train_losses = []
val_losses = []

class AccuracyHistoryCallback(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs=None):
        train_acc = logs.get('accuracy')
        val_acc = logs.get('val_accuracy')
        train_accs.append(train_acc)
        val_accs.append(val_acc)
        train_loss = logs.get('loss')
        val_loss = logs.get('val_loss')
        train_losses.append(train_loss)
        val_losses.append(val_loss)      

def lr_schedule(epoch):
    #if(MAX_FRAMES == 30):
        if epoch < 5:
            return 0.0001
        elif epoch < 12:
            return 0.00005
        else:
            return 0.00001
    #lse:
    #   if epoch < 5:
    #       return 0.00001
    #   elif epoch < 10:
    #       return 0.00001
    #   else:
    #       return 0.000005
    
accuracy_history = AccuracyHistoryCallback()       
top2_acc = lambda y_true, y_pred: top_k_categorical_accuracy(y_true, y_pred, k=2)
# Create a learning rate scheduler callback
def get_callbacks(filepath):
    return [
            keras.callbacks.EarlyStopping(
            monitor="val_accuracy",
            patience = 5,
            restore_best_weights=True
        ),
            keras.callbacks.ReduceLROnPlateau(
            monitor = "val_accuracy",
            factor = 0.5,
            patience = 3
        ),
            keras.callbacks.ModelCheckpoint(
            filepath,
            save_weights_only=True,
            save_best_only=True,
            verbose=1
            ),
            accuracy_history,
            lr_scheduler,
    ]

def GET_MODEL(MAX_FRAMES, MAX_KEYPOINTS):
    model = keras.models.Sequential()
    model.add(Dense(units=1024, input_shape=(MAX_FRAMES, MAX_KEYPOINTS)))
    model.add(LayerNormalization())
    model.add(Dropout(0.6))
    model.add(GRU(units=2048, return_sequences=True))
    model.add(LayerNormalization())
    model.add(Dropout(0.5))
    model.add(GRU(units=1024, return_sequences=True))
    model.add(LayerNormalization())
    model.add(Dropout(0.5))
    model.add(GRU(units=512, return_sequences=True))
    model.add(LayerNormalization())
    model.add(Dropout(0.5))
    model.add(GRU(units=256, return_sequences=True))
    model.add(LayerNormalization())
    model.add(Dropout(0.5))
    model.add(GRU(units=128, return_sequences=False))
    model.add(LayerNormalization())
    model.add(Dropout(0.1))
    model.add(Dense(units=20, activation='softmax'))
    optimizer = optimizers.Adam(learning_rate=0.0001)
    model.compile(optimizer=optimizer,
              loss="categorical_crossentropy",
              metrics=["accuracy",top2_acc])
    return model

# %%
all_classes = np.load('NPY_SPLITS/ALL_CLASSES.npy',allow_pickle=True)

# %%
MAX_KEYPOINTS = 134
lr_scheduler = LearningRateScheduler(lr_schedule)

for MAX_FRAMES in [30]:
    print(f"Training for frame count: {MAX_FRAMES}")
    for i in range(0, 5):
        print(f"Split: {i+1} Frames: {MAX_FRAMES}")
        train_filename = f"NPY_SPLITS/train_list_HOL_{MAX_FRAMES}_{i}.npy"
        train_label_filename = f"NPY_SPLITS/train_label_HOL_{MAX_FRAMES}_{i}.npy"
        test_filename = f"NPY_SPLITS/test_list_HOL_{MAX_FRAMES}_{i}.npy"
        test_label_filename = f"NPY_SPLITS/test_label_HOL_{MAX_FRAMES}_{i}.npy"
        train_list = np.load(train_filename, allow_pickle=True)
        train_label = np.load(train_label_filename, allow_pickle=True)
        test_list =  np.load(test_filename, allow_pickle=True)
        test_label = np.load(test_label_filename, allow_pickle=True)
        filepath_weights = f"SAVED_MODELS/IT6_HOL_{MAX_FRAMES}_{i}.hdf5"
        y_train_one_hot = np_utils.to_categorical(train_label)
        y_test_one_hot = np_utils.to_categorical(test_label)
        train_accs = []
        val_accs = []
        train_losses = []
        val_losses = []
        model=GET_MODEL(MAX_FRAMES, MAX_KEYPOINTS)
        model.fit(train_list, y_train_one_hot, epochs=16, batch_size=64, 
                  validation_data=(test_list, y_test_one_hot), 
                  callbacks=get_callbacks(filepath_weights))
        del train_filename, train_label_filename, test_filename, \
            test_label_filename, train_list, train_label, test_list, \
                test_label, model
        fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(8, 8))
        epochs = range(1, len(train_accs) + 1)
        # Plot the training and validation accuracy
        ax1.plot(epochs, train_accs, 'b', label='Training accuracy')
        ax1.plot(epochs, val_accs, 'r', label='Validation accuracy')
        ax1.set_title(f"Training and Validation Accuracy {MAX_FRAMES} Frames - IT6")
        ax1.set_xlabel('Epochs')
        ax1.set_ylabel('Accuracy')
        ax1.legend()
        
        # Plot the training and validation loss
        ax2.plot(epochs, train_losses, 'b', label='Training loss')
        ax2.plot(epochs, val_losses, 'r', label='Validation loss')
        ax2.set_title(f"Training and Validation Loss {MAX_FRAMES} Frames - IT6")
        ax2.set_xlabel('Epochs')
        ax2.set_ylabel('Loss')
        ax2.legend()
        
        # Adjust spacing between subplots
        plt.tight_layout()
        
        # Save the combined subplot to a file
        plt_filename = f"IT6-combined_plots{MAX_FRAMES}_{i}.png"
        plt.savefig(plt_filename)
        print("*************************DONE******************************")
# Out:
# Training for frame count: 30
# Split: 1 Frames: 30
# Epoch 1/16
# 411/411 [==============================] - ETA: 0s - loss: 2.9346 - accuracy: 0.1086 - <lambda>: 0.1933
# Epoch 1: val_loss improved from inf to 2.77913, saving model to SAVED_MODELS\IT6_HOL_30_0.hdf5
# 411/411 [==============================] - 79s 166ms/step - loss: 2.9346 - accuracy: 0.1086 - <lambda>: 0.1933 - val_loss: 2.7791 - val_accuracy: 0.1699 - val_<lambda>: 0.2807 - lr: 1.0000e-04
# Epoch 2/16
# 411/411 [==============================] - ETA: 0s - loss: 1.3938 - accuracy: 0.5209 - <lambda>: 0.6934
# Epoch 2: val_loss improved from 2.77913 to 1.13014, saving model to SAVED_MODELS\IT6_HOL_30_0.hdf5
# 411/411 [==============================] - 68s 165ms/step - loss: 1.3938 - accuracy: 0.5209 - <lambda>: 0.6934 - val_loss: 1.1301 - val_accuracy: 0.6124 - val_<lambda>: 0.7790 - lr: 1.0000e-04
# Epoch 3/16
# 411/411 [==============================] - ETA: 0s - loss: 0.4918 - accuracy: 0.8400 - <lambda>: 0.9331
# Epoch 3: val_loss improved from 1.13014 to 0.82630, saving model to SAVED_MODELS\IT6_HOL_30_0.hdf5
# 411/411 [==============================] - 68s 166ms/step - loss: 0.4918 - accuracy: 0.8400 - <lambda>: 0.9331 - val_loss: 0.8263 - val_accuracy: 0.7674 - val_<lambda>: 0.8654 - lr: 1.0000e-04
# Epoch 4/16
# 411/411 [==============================] - ETA: 0s - loss: 0.2530 - accuracy: 0.9254 - <lambda>: 0.9758
# Epoch 4: val_loss improved from 0.82630 to 0.65830, saving model to SAVED_MODELS\IT6_HOL_30_0.hdf5
# 411/411 [==============================] - 68s 166ms/step - loss: 0.2530 - accuracy: 0.9254 - <lambda>: 0.9758 - val_loss: 0.6583 - val_accuracy: 0.8090 - val_<lambda>: 0.9278 - lr: 1.0000e-04
# Epoch 5/16
# 411/411 [==============================] - ETA: 0s - loss: 0.1314 - accuracy: 0.
16
# 411/411 [==============================] - ETA: 0s - loss: 0.0096 - accuracy: 0.9970 - <lambda>: 1.0000
# Epoch 16: val_loss did not improve from 0.53678
# 411/411 [==============================] - 69s 167ms/step - loss: 0.0096 - accuracy: 0.9970 - <lambda>: 1.0000 - val_loss: 0.7423 - val_accuracy: 0.8383 - val_<lambda>: 0.9407 - lr: 1.0000e-05
# *************************DONE******************************
# Split: 2 Frames: 30
# Epoch 1/16
#   6/411 [..............................] - ETA: 1:00 - loss: 3.8250 - accuracy: 0.0495 - <lambda>: 0.0911WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0668s vs `on_train_batch_end` time: 0.0770s). Check your callbacks.
# 411/411 [==============================] - ETA: 0s - loss: 2.9849 - accuracy: 0.1027 - <lambda>: 0.1820
# Epoch 1: val_loss improved from inf to 2.39989, saving model to SAVED_MODELS\IT6_HOL_30_1.hdf5
# 411/411 [==============================] - 76s 170ms/step - loss: 2.9849 - accuracy: 0.1027 - <lambda>: 0.1820 - val_loss: 2.3999 - val_accuracy: 0.2037 - val_<lambda>: 0.3633 - lr: 1.0000e-04
# Epoch 2/16
# 411/411 [==============================] - ETA: 0s - loss: 1.3113 - accuracy: 0.5549 - <lambda>: 0.7192
# Epoch 2: val_loss improved from 2.39989 to 1.93062, saving model to SAVED_MODELS\IT6_HOL_30_1.hdf5
# 411/411 [==============================] - 69s 168ms/step - loss: 1.3113 - accuracy: 0.5549 - <lambda>: 0.7192 - val_loss: 1.9306 - val_accuracy: 0.4482 - val_<lambda>: 0.6199 - lr: 1.0000e-04
# Epoch 3/16
# 411/411 [==============================] - ETA: 0s - loss: 0.3802 - accuracy: 0.8793 - <lambda>: 0.9572
# Epoch 3: val_loss improved from 1.93062 to 1.55216, saving model to SAVED_MODELS\IT6_HOL_30_1.hdf5
# 411/411 [==============================] - 69s 168ms/step - loss: 0.3802 - accuracy: 0.8793 - <lambda>: 0.9572 - val_loss: 1.5522 - val_accuracy: 0.6269 - val_<lambda>: 0.7908 - lr: 1.0000e-04
# Epoch 4/16
# 411/411 [==============================] - ETA: 0s - loss: 0.1350 - accuracy: 0.9630 - <lambda>: 0.9926
# Epoch 4: val_loss did not improve from 1.55216
# 411/411 [==============================] - 69s 168ms/step - loss: 0.1350 - accuracy: 0.9630 - <lambda>: 0.9926 - val_loss: 1.7002 - val_accuracy: 0.6640 - val_<lambda>: 0.8083 - lr: 1.0000e-04
# Epoch 5/16
# 411/411 [==============================] - ETA: 0s - loss: 0.0718 - accuracy: 0.9808 - <lambda>: 0.9977
# Epoch 5: val_loss did not improve from 1.55216
# 411/411 [==============================] - 69s 168ms/step - loss: 0.0718 - accuracy: 0.9808 - <lambda>: 0.9977 - val_loss: 1.6712 - val_accuracy: 0.6678 - val_<lambda>: 0.8208 - lr: 1.0000e-04
# Epoch 6/16
# 411/411 [==============================] - ETA: 0s - loss: 0.0255 - accuracy: 0.9947 - <lambda>: 0.9997
# Epoch 6: val_loss improved from 1.55216 to 1.46573, saving model to SAVED_MODELS\IT6_HOL_30_1.hdf5
# 411/411 [==============================] - 69s 168ms/step - loss: 0.0255 - accuracy: 0.9947 - <lambda>: 0.9997 - val_loss: 1.4657 - val_accuracy: 0.7375 - val_<lambda>: 0.8472 - lr: 5.0000e-05
# Epoch 7/16
# 411/411 [==============================] - ETA: 0s - loss: 0.0217 - accuracy: 0.9947 - <lambda>: 0.9998
# Epoch 7: val_loss did not improve from 1.46573
# 411/411 [==============================] - 69s 168ms/step - loss: 0.
[==============================] - ETA: 0s - loss: 0.1282 - accuracy: 0.9658 - <lambda>: 0.9912
# Epoch 5: val_loss did not improve from 0.73159
# 411/411 [==============================] - 69s 168ms/step - loss: 0.1282 - accuracy: 0.9658 - <lambda>: 0.9912 - val_loss: 0.8547 - val_accuracy: 0.7985 - val_<lambda>: 0.9071 - lr: 1.0000e-04
# Epoch 6/16
# 411/411 [==============================] - ETA: 0s - loss: 0.0612 - accuracy: 0.9830 - <lambda>: 0.9968
# Epoch 6: val_loss improved from 0.73159 to 0.67106, saving model to SAVED_MODELS\IT6_HOL_30_2.hdf5
# 411/411 [==============================] - 69s 169ms/step - loss: 0.0612 - accuracy: 0.9830 - <lambda>: 0.9968 - val_loss: 0.6711 - val_accuracy: 0.8467 - val_<lambda>: 0.9289 - lr: 5.0000e-05
# Epoch 7/16
# 411/411 [==============================] - ETA: 0s - loss: 0.0486 - accuracy: 0.9863 - <lambda>: 0.9984
# Epoch 7: val_loss did not improve from 0.67106
# 411/411 [==============================] - 69s 169ms/step - loss: 0.0486 - accuracy: 0.9863 - <lambda>: 0.9984 - val_loss: 0.6945 - val_accuracy: 0.8397 - val_<lambda>: 0.9293 - lr: 5.0000e-05
# Epoch 8/16
# 411/411 [==============================] - ETA: 0s - loss: 0.0412 - accuracy: 0.9876 - <lambda>: 0.9981
# Epoch 8: val_loss improved from 0.67106 to 0.65132, saving model to SAVED_MODELS\IT6_HOL_30_2.hdf5
# 411/411 [==============================] - 69s 169ms/step - loss: 0.0412 - accuracy: 0.9876 - <lambda>: 0.9981 - val_loss: 0.6513 - val_accuracy: 0.8596 - val_<lambda>: 0.9306 - lr: 5.0000e-05
# Epoch 9/16
# 411/411 [==============================] - ETA: 0s - loss: 0.0412 - accuracy: 0.9871 - <lambda>: 0.9989
# Epoch 9: val_loss did not improve from 0.65132
# 411/411 [==============================] - 69s 168ms/step - loss: 0.0412 - accuracy: 0.9871 - <lambda>: 0.9989 - val_loss: 0.7727 - val_accuracy: 0.8317 - val_<lambda>: 0.9306 - lr: 5.0000e-05
# Epoch 10/16
# 411/411 [==============================] - ETA: 0s - loss: 0.0312 - accuracy: 0.9908 - <lambda>: 0.9990
# Epoch 10: val_loss did not improve from 0.65132
# 411/411 [==============================] - 69s 169ms/step - loss: 0.0312 - accuracy: 0.9908 - <lambda>: 0.9990 - val_loss: 0.6727 - val_accuracy: 0.8603 - val_<lambda>: 0.9282 - lr: 5.0000e-05
# Epoch 11/16
# 411/411 [==============================] - ETA: 0s - loss: 0.0361 - accuracy: 0.9887 - <lambda>: 0.9990
# Epoch 11: val_loss did not improve from 0.65132
# 411/411 [==============================] - 69s 169ms/step - loss: 0.0361 - accuracy: 0.9887 - <lambda>: 0.9990 - val_loss: 0.7772 - val_accuracy: 0.8424 - val_<lambda>: 0.9328 - lr: 5.0000e-05
# Epoch 12/16
# 411/411 [==============================] - ETA: 0s - loss: 0.0237 - accuracy: 0.9928 - <lambda>: 0.9995
# Epoch 12: val_loss improved from 0.65132 to 0.64336, saving model to SAVED_MODELS\IT6_HOL_30_2.hdf5
# 411/411 [==============================] - 70s 170ms/step - loss: 0.0237 - accuracy: 0.9928 - <lambda>: 0.9995 - val_loss: 0.6434 - val_accuracy: 0.8735 - val_<lambda>: 0.9426 - lr: 5.0000e-05
# Epoch 13/16
# 411/411 [==============================] - ETA: 0s - loss: 0.0120 - accuracy: 0.9962 - <lambda>: 1.0000
# Epoch 13: val_loss did not improve from 0.64336
# 411/411 [==============================] - 69s 169ms/step - loss: 0.0120 - accuracy: 0.9962 - <lambda>: 1.0000 - val_loss: 0.6634 - val_accuracy: 0.8699 - val_<lambda>: 0.9406 - lr: 1.0000e-05
# Epoch 14/16
# 411/411 [==============================] - ETA: 0s - loss: 0.0092 - accuracy: 0.9971 - <lambda>: 1.0000
# Epoch 14: val_loss did not improve from 0.64336
# 411/411 [==============================] - 69s 169ms/step - loss: 0.0092 - accuracy: 0.9971 - <lambda>: 1.0000 - val_loss: 0.6851 - val_accuracy: 0.8654 - val_<lambda>: 0.9397 - lr: 1.0000e-05
# Epoch 15/16
# 411/411 [==============================] - ETA: 0s - loss: 0.0080 - accuracy: 0.9976 - <lambda>: 1.0000
# Epoch 15: val_loss did not improve from 0.64336
# 411/411 [==============================] - 69s 169ms/step - loss: 0.0080 - accuracy: 0.9976 - <lambda>: 1.0000 - val_loss: 0.6766 - val_accuracy: 0.8739 - val_<lambda>: 0.9413 - lr: 1.0000e-05
# Epoch 16/16
# 411/411 [==============================] - ETA: 0s - loss: 0.0080 - accuracy: 0.9976 - <lambda>: 1.0000
# Epoch 16: val_loss did not improve from 0.64336
# 411/411 [==============================] - 69s 169ms/step - loss: 0.0080 - accuracy: 0.9976 - <lambda>: 1.0000 - val_loss: 0.6490 - val_accuracy: 0.8747 - val_<lambda>: 0.9463 - lr: 1.0000e-05
# *************************DONE******************************
# Split: 4 Frames: 30
# Epoch 1/16
#   6/413 [..............................] - ETA: 1:01 - loss: 3.8374 - accuracy: 0.0495 - <lambda>: 0.0938WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0678s vs `on_train_batch_end` time: 0.0775s). Check your callbacks.
# 413/413 [==============================] - ETA: 0s - loss: 2.7847 - accuracy: 0.1474 - <lambda>: 0.2490
# Epoch 1: val_loss improved from inf to 2.19219, saving model to SAVED_MODELS\IT6_HOL_30_3.hdf5
# 413/413 [==============================] - 76s 171ms/step - loss: 2.7847 - accuracy: 0.1474 - <lambda>: 0.2490 - val_loss: 2.1922 - val_accuracy: 0.2762 - val_<lambda>: 0.4425 - lr: 1.0000e-04
# Epoch 2/16
# 413/413 [==============================] - ETA: 0s - loss: 1.2514 - accuracy: 0.5712 - <lambda>: 0.7313
# Epoch 2: val_loss improved from 2.19219 to 1.22520, saving model to SAVED_MODELS\IT6_HOL_30_3.hdf5
# 413/413 [==============================] - 70s 168ms/step - loss: 1.2514 - accuracy: 0.5712 - <lambda>: 0.7313 - val_loss: 1.2252 - val_accuracy: 0.5909 - val_<lambda>: 0.7630 - lr: 1.0000e-04
# Epoch 3/16
# 413/413 [==============================] - ETA: 0s - loss: 0.4805 - accuracy: 0.8485 - <lambda>: 0.9378
# Epoch 3: val_loss improved from 1.22520 to 0.86863, saving model to SAVED_MODELS\IT6_HOL_30_3.hdf5
# 413/413 [==============================] - 70s 169ms/step - loss: 0.4805 - accuracy: 0.8485 - <lambda>: 0.9378 - val_loss: 0.8686 - val_accuracy: 0.7111 - val_<lambda>: 0.8457 - lr: 1.0000e-04
# Epoch 4/16
# 413/413 [==============================] - ETA: 0s - loss: 0.2391 - accuracy: 0.9297 - <lambda>: 0.9786
# Epoch 4: val_loss did not improve from 0.86863
# 413/413 [==============================] - 69s 168ms/step - loss: 0.2391 - accuracy: 0.9297 - <lambda>: 0.9786 - val_loss: 0.8972 - val_accuracy: 0.7498 - val_<lambda>: 0.8729 - lr: 1.0000e-04
# Epoch 5/16
# 412/413 [============================>.] - ETA: 0s - loss: 0.1303 - accuracy: 0.9625 - <lambda>: 0.9914
# Epoch 5: val_loss improved from 0.86863 to 0.77125, saving model to SAVED_MODELS\IT6_HOL_30_3.hdf5
# 413/413 [==============================] - 70s 169ms/step - loss: 0.1303 - accuracy: 0.9625 - <lambda>: 0.9914 - val_loss: 0.7713 - val_accuracy: 0.7800 - val_<lambda>: 0.8911 - lr: 1.0000e-04
# Epoch 6/16
# 413/413 [==============================] - ETA: 0s - loss: 0.0604 - accuracy: 0.9844 - <lambda>: 0.9976
# Epoch 6: val_loss did not improve from 0.77125
# 413/413 [==============================] - 69s 168ms/step - loss: 0.0604 - accuracy: 0.9844 - <lambda>: 0.9976 - val_loss: 0.9349 - val_accuracy: 0.7488 - val_<lambda>: 0.8685 - lr: 5.0000e-05
# Epoch 7/16
# 413/413 [==============================] - ETA: 0s - loss: 0.0454 - accuracy: 0.9882 - <lambda>: 0.9984
# Epoch 7: val_loss did not improve from 0.77125
# 413/413 [==============================] - 70s 168ms/step - loss: 0.0454 - accuracy: 0.9882 - <lambda>: 0.9984 - val_loss: 0.9970 - val_accuracy: 0.7496 - val_<lambda>: 0.8617 - lr: 5.0000e-05
# Epoch 8/16
# 413/413 [==============================] - ETA: 0s - loss: 0.0425 - accuracy: 0.9880 - <lambda>: 0.9989
# Epoch 8: val_loss did not improve from 0.77125
# 413/413 [==============================] - 69s 168ms/step - loss: 0.0425 - accuracy: 0.9880 - <lambda>: 0.9989 - val_loss: 1.0805 - val_accuracy: 0.7515 - val_<lambda>: 0.8489 - lr: 2.5000e-05
# Epoch 9/16
# 413/413 [==============================] - ETA: 0s - loss: 0.0444 - accuracy: 0.9871 - <lambda>: 0.9986
# Epoch 9: val_loss did not improve from 0.77125
# 413/413 [==============================] - 69s 168ms/step - loss: 0.0444 - accuracy: 0.9871 - <lambda>: 0.9986 - val_loss: 1.1709 - val_accuracy: 0.7332 - val_<lambda>: 0.8304 - lr: 5.0000e-05
# Epoch 10/16
# 412/413 [============================>.] - ETA: 0s - loss: 0.0332 - accuracy: 0.9901 - <lambda>: 0.9994
# Epoch 10: val_loss did not improve from 0.77125
# 413/413 [==============================] - 70s 169ms/step - loss: 0.0332 - accuracy: 0.9901 - <lambda>: 0.9994 - val_loss: 1.1766 - val_accuracy: 0.7397 - val_<lambda>: 0.8418 - lr: 5.0000e-05
# *************************DONE******************************
# Split: 5 Frames: 30
# Epoch 1/16
#   6/402 [..............................] - ETA: 59s - loss: 3.7010 - accuracy: 0.0547 - <lambda>: 0.1042  WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0687s vs `on_train_batch_end` time: 0.0764s). Check your callbacks.
# 402/402 [==============================] - ETA: 0s - loss: 3.0424 - accuracy: 0.0840 - <lambda>: 0.1555
# Epoch 1: val_loss improved from inf to 2.56118, saving model to SAVED_MODELS\IT6_HOL_30_4.hdf5
# 402/402 [==============================] - 77s 175ms/step - loss: 3.0424 - accuracy: 0.0840 - <lambda>: 0.1555 - val_loss: 2.5612 - val_accuracy: 0.2042 - val_<lambda>: 0.3076 - lr: 1.0000e-04
# Epoch 2/16
# 402/402 [==============================] - ETA: 0s - loss: 1.6514 - accuracy: 0.4360 - <lambda>: 0.6035
# Epoch 2: val_loss improved from 2.56118 to 1.07926, saving model to SAVED_MODELS\IT6_HOL_30_4.hdf5
# 402/402 [==============================] - 69s 171ms/step - loss: 1.6514 - accuracy: 0.4360 - <lambda>: 0.6035 - val_loss: 1.0793 - val_accuracy: 0.6437 - val_<lambda>: 0.8028 - lr: 1.0000e-04
# Epoch 3/16
# 402/402 [==============================] - ETA: 0s - loss: 0.5727 - accuracy: 0.8116 - <lambda>: 0.9194
# Epoch 3: val_loss improved from 1.07926 to 0.66808, saving model to SAVED_MODELS\IT6_HOL_30_4.hdf5
# 402/402 [==============================] - 69s 171ms/step - loss: 0.5727 - accuracy: 0.8116 - <lambda>: 0.9194 - val_loss: 0.6681 - val_accuracy: 0.8118 - val_<lambda>: 0.9054 - lr: 1.0000e-04
# Epoch 4/16
# 402/402 [==============================] - ETA: 0s - loss: 0.2466 - accuracy: 0.9271 - <lambda>: 0.9777
# Epoch 4: val_loss did not improve from 0.66808
# 402/402 [==============================] - 69s 171ms/step - loss: 0.2466 - accuracy: 0.9271 - <lambda>: 0.9777 - val_loss: 0.6867 - val_accuracy: 0.8216 - val_<lambda>: 0.8938 - lr: 1.0000e-04
# Epoch 5/16
# 402/402 [==============================] - ETA: 0s - loss: 0.1373 - accuracy: 0.9601 - <lambda>: 0.9904
# Epoch 5: val_loss did not improve from 0.66808
# 402/402 [==============================] - 69s 171ms/step - loss: 0.1373 - accuracy: 0.9601 - <lambda>: 0.9904 - val_loss: 0.6723 - val_accuracy: 0.8364 - val_<lambda>: 0.9084 - lr: 1.0000e-04
# Epoch 6/16
# 402/402 [==============================] - ETA: 0s - loss: 0.0602 - accuracy: 0.9844 - <lambda>: 0.9976
# Epoch 6: val_loss improved from 0.66808 to 0.57566, saving model to SAVED_MODELS\IT6_HOL_30_4.hdf5
# 402/402 [==============================] - 69s 171ms/step - loss: 0.0602 - accuracy: 0.9844 - <lambda>: 0.9976 - val_loss: 0.5757 - val_accuracy: 0.8434 - val_<lambda>: 0.9224 - lr: 5.0000e-05
# Epoch 7/16
# 402/402 [==============================] - ETA: 0s - loss: 0.0395 - accuracy: 0.9900 - <lambda>: 0.9991
# Epoch 7: val_loss did not improve from 0.57566
# 402/402 [==============================] - 68s 170ms/step - loss: 0.0395 - accuracy: 0.9900 - <lambda>: 0.9991 - val_loss: 0.6195 - val_accuracy: 0.8483 - val_<lambda>: 0.9113 - lr: 5.0000e-05
# Epoch 8/16
# 402/402 [==============================] - ETA: 0s - loss: 0.0418 - accuracy: 0.9884 - <lambda>: 0.9989
# Epoch 8: val_loss did not improve from 0.57566
# 402/402 [==============================] - 69s 170ms/step - loss: 0.0418 - accuracy: 0.9884 - <lambda>: 0.9989 - val_loss: 0.6174 - val_accuracy: 0.8550 - val_<lambda>: 0.9212 - lr: 5.0000e-05
# Epoch 9/16
# 402/402 [==============================] - ETA: 0s - loss: 0.0349 - accuracy: 0.9903 - <lambda>: 0.9993
# Epoch 9: val_loss did not improve from 0.57566
# 402/402 [==============================] - 68s 170ms/step - loss: 0.0349 - accuracy: 0.9903 - <lambda>: 0.9993 - val_loss: 0.6754 - val_accuracy: 0.8402 - val_<lambda>: 0.9152 - lr: 5.0000e-05
# Epoch 10/16
# 402/402 [==============================] - ETA: 0s - loss: 0.0274 - accuracy: 0.9927 - <lambda>: 0.9993
# Epoch 10: val_loss did not improve from 0.57566
# 402/402 [==============================] - 68s 170ms/step - loss: 0.0274 - accuracy: 0.9927 - <lambda>: 0.9993 - val_loss: 0.6494 - val_accuracy: 0.8645 - val_<lambda>: 0.9246 - lr: 5.0000e-05
# Epoch 11/16
# 402/402 [==============================] - ETA: 0s - loss: 0.0290 - accuracy: 0.9920 - <lambda>: 0.9994
# Epoch 11: val_loss did not improve from 0.57566
# 402/402 [==============================] - 68s 170ms/step - loss: 0.0290 - accuracy: 0.9920 - <lambda>: 0.9994 - val_loss: 0.6216 - val_accuracy: 0.8547 - val_<lambda>: 0.9309 - lr: 5.0000e-05
# Epoch 12/16
# 402/402 [==============================] - ETA: 0s - loss: 0.0312 - accuracy: 0.9907 - <lambda>: 0.9990
# Epoch 12: val_loss did not improve from 0.57566
# 402/402 [==============================] - 68s 170ms/step - loss: 0.0312 - accuracy: 0.9907 - <lambda>: 0.9990 - val_loss: 0.7997 - val_accuracy: 0.8327 - val_<lambda>: 0.9024 - lr: 5.0000e-05
# Epoch 13/16
# 402/402 [==============================] - ETA: 0s - loss: 0.0104 - accuracy: 0.9972 - <lambda>: 1.0000
# Epoch 13: val_loss improved from 0.57566 to 0.54960, saving model to SAVED_MODELS\IT6_HOL_30_4.hdf5
# 402/402 [==============================] - 68s 170ms/step - loss: 0.0104 - accuracy: 0.9972 - <lambda>: 1.0000 - val_loss: 0.5496 - val_accuracy: 0.8774 - val_<lambda>: 0.9379 - lr: 1.0000e-05
# Epoch 14/16
# 402/402 [==============================] - ETA: 0s - loss: 0.0086 - accuracy: 0.9977 - <lambda>: 1.0000
# Epoch 14: val_loss improved from 0.54960 to 0.52134, saving model to SAVED_MODELS\IT6_HOL_30_4.hdf5
# 402/402 [==============================] - 68s 170ms/step - loss: 0.0086 - accuracy: 0.9977 - <lambda>: 1.0000 - val_loss: 0.5213 - val_accuracy: 0.8849 - val_<lambda>: 0.9456 - lr: 1.0000e-05
# Epoch 15/16
# 402/402 [==============================] - ETA: 0s - loss: 0.0078 - accuracy: 0.9978 - <lambda>: 1.0000
# Epoch 15: val_loss did not improve from 0.52134
# 402/402 [==============================] - 68s 169ms/step - loss: 0.0078 - accuracy: 0.9978 - <lambda>: 1.0000 - val_loss: 0.5729 - val_accuracy: 0.8760 - val_<lambda>: 0.9403 - lr: 1.0000e-05
# Epoch 16/16
# 402/402 [==============================] - ETA: 0s - loss: 0.0077 - accuracy: 0.9981 - <lambda>: 1.0000
# Epoch 16: val_loss did not improve from 0.52134
# 402/402 [==============================] - 68s 169ms/step - loss: 0.0077 - accuracy: 0.9981 - <lambda>: 1.0000 - val_loss: 0.6096 - val_accuracy: 0.8720 - val_<lambda>: 0.9353 - lr: 1.0000e-05
# *************************DONE******************************

# %%
for MAX_FRAMES in [30]:
    losses = []
    accuracies = []
    k_accuracies = []
    print(f"Eval for frame count: {MAX_FRAMES}")
    for i in range(0, 5):
        test_filename = f"NPY_SPLITS/test_list_HOL_{MAX_FRAMES}_{i}.npy"
        test_label_filename = f"NPY_SPLITS/test_label_HOL_{MAX_FRAMES}_{i}.npy"
        
        test_list_val =  np.load(test_filename, allow_pickle=True)
        test_label_val = np.load(test_label_filename, allow_pickle=True)
        y_train_one_hot_val = np_utils.to_categorical(test_label_val)
        filepath_weights = f"SAVED_MODELS/IT6_HOL_{MAX_FRAMES}_{i}.hdf5"
        model=GET_MODEL(MAX_FRAMES, MAX_KEYPOINTS)        
        model.load_weights(filepath_weights)
        loss, accuracy, k_accuracy = model.evaluate(test_list_val, y_train_one_hot_val)
        losses.append(loss)
        accuracies.append(accuracy)
        k_accuracies.append(k_accuracy)
    avg_loss = sum(losses) / len(losses)
    avg_accuracy = sum(accuracies) / len(accuracies)
    avg_k_accuracy = sum(k_accuracies) / len(k_accuracies)
    # Print the average results
    print(f"Average Loss with {MAX_FRAMES} frames model:", avg_loss)
    print(f"Average Accuracy with {MAX_FRAMES} frames model:", avg_accuracy*100)
    print(f"Average K-Accuracy with {MAX_FRAMES} frames model:", avg_k_accuracy*100)
# Out:
# Eval for frame count: 30
# 225/225 [==============================] - 13s 31ms/step - loss: 0.5368 - accuracy: 0.8579 - <lambda>: 0.9528
# 225/225 [==============================] - 12s 31ms/step - loss: 1.4657 - accuracy: 0.7375 - <lambda>: 0.8472
# 225/225 [==============================] - 13s 31ms/step - loss: 0.6434 - accuracy: 0.8735 - <lambda>: 0.9426
# 223/223 [==============================] - 12s 33ms/step - loss: 0.7713 - accuracy: 0.7800 - <lambda>: 0.8911
# 243/243 [==============================] - 13s 33ms/step - loss: 0.5213 - accuracy: 0.8849 - <lambda>: 0.9456
# Average Loss with 30 frames model: 0.787690532207489
# Average Accuracy with 30 frames model: 82.67619967460632
# Average K-Accuracy with 30 frames model: 91.58765435218811
